# %%
string = "python"

# %% [markdown]
# # 1. string.capitalize()

# %%
string = "python"
string.capitalize()
# Out:
# 'Python'

# %% [markdown]
# # 2.string.casefold()

# %%
string.casefold()
# Out:
# 'python'
